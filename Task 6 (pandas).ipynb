# %%
import pandas as pd
df_excel = pd.read_excel('/content/sangeeta.xlsx')
print(df_excel)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN        NaN        NaN
# 1          NaN         NaN         NaN         NaN        NaN        NaN
# 2          NaN         NaN         NaN         NaN    REF NO.   EMP_NAME
# 3          NaN         NaN         NaN         NaN       1002      ANMOL
# 4          NaN         NaN         NaN         NaN       1003        ANU
# 5          NaN         NaN         NaN         NaN       1004       ASHA
# 6          NaN         NaN         NaN         NaN       1005      DISHA
# 7          NaN         NaN         NaN         NaN       1006      KAMAL
# 8          NaN         NaN         NaN         NaN       1001      NEERU
# 9          NaN         NaN         NaN         NaN       1007      NITIN
# 10         NaN         NaN         NaN         NaN       1008      RAHUL
# 11         NaN         NaN         NaN         NaN       1009      REKHA
# ...
