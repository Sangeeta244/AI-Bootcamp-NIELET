# %%
import cv2
from google.colab.patches import cv2_imshow

# load and display image
image = cv2.imread('/content/sangeeta.jpeg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=326x155>
